# %% [markdown]
# #  Tuple Data Structure

# %%
a=(4,5,6,7)
b=('a','b','c','d','e','f')
c=(1,'a',2,3,'b','c','d',6,7)
a
b
c
d=('a','b','c','d','e',(1,2,3,4),'g',"whats!")
d
a[2]
a[-1]
b[0:3]
a.index(7)
b.index('c')
e=a+b+c
print(e)
t1=("sarwar maruf jebon",23,'ulipur')
(name,age,adress)=t1
name
age
adress

#tuple function:::
max(a)
2 not in a
#del a
a
# Out:
# (4, 5, 6, 7, 'a', 'b', 'c', 'd', 'e', 'f', 1, 'a', 2, 3, 'b', 'c', 'd', 6, 7)
# (4, 5, 6, 7)

# %% [markdown]
# # List data Structure:
# ## wow!
# ###  :-)

# %%
a=[2,4,5,6]
a[-3:-1]

fruits=['apple',"banana",'orange','grapes']
print(fruits)
#fruits.apppend([mango,jackfruit],"kamrangga")
fruits.insert(1,'mango')
print(fruits)
fruits.extend("amloki")
print(fruits)
#del fruits
fruits
fruits.reverse()
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'grapes']
# ['apple', 'mango', 'banana', 'orange', 'grapes']
# ['apple', 'mango', 'banana', 'orange', 'grapes', 'a', 'm', 'l', 'o', 'k', 'i']
# ['i', 'k', 'o', 'l', 'm', 'a', 'grapes', 'orange', 'banana', 'mango', 'apple']

# %%
from matplotlib import pyplot as plt
years=[2022,2025,2030,2032,2034,2035,2040]
gdp=[300.2,543.3,1075.9,2860.5,5979.6,10289.7,14958.3]
plt.plot(years,gdp,color='green',marker='o',linestyle='solid')
plt.title("Sarwar Maruf's Bank Balance")
plt.ylabel("billions on $")
plt.xlabel("year's")
plt.show()

# %%
Heros=["Manna",'Joshim',"Bappa Raj","Jayed khan"]
num_oscar=[11,5,1,3]
xs=[i+0.1 for i,_ in enumerate(Heros)]
plt.bar(xs,num_oscar)

plt.ylabel("# Of academy award")
plt.title("My favourite Movie")
plt.xticks([i+0.0 for i,_ in enumerate(Heros)],Heros)
plt.show()
